# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
from lightgbm import LGBMRegressor

from data import MaskedData, Data, Model, Feature, Features, TARGET, DATE_COLUMN

# %% [markdown]
# ### Set parameters

# %%
params = {
    'boosting_type': 'gbdt',
    'objective': 'tweedie',
    'tweedie_variance_power': 1.1,
    'metric': 'rmse',
    'subsample': 0.5,
    'subsample_freq': 1,
    'learning_rate': 0.03,
    'num_leaves': 2**11-1,
    'min_data_in_leaf': 2**12-1,
    'feature_fraction': 0.5,
    # 'n_estimators': 1400,
    'n_estimators': 10,
    'boost_from_average': False,
}

leads = [1, 7, 14]
retrain_frequency = 60  # retrain every 60 days
first_forecast_date = pd.Timestamp("2013-01-01")  # we assume that on the forecast date, we have observed the sales of that date

# %% [markdown]
# ### Read features

# %%
data = (
    pd.read_parquet("features.parquet")
    .assign(date=lambda df: pd.to_datetime(df["date"]))
    .set_index("date")
    .sort_index()
)

features = Features(feature_names=[col for col in data.columns if col not in [TARGET, DATE_COLUMN]])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 4
#       1 data = (
#       2     pd.read_parquet("features.parquet")
#       3     .assign(date=lambda df: pd.to_datetime(df["date"]))
# ----> 4     .set_index("date")
#       5     .sort_index()
#       6 )
#       8 features = Features(feature_names=[col for col in data.columns if col not in [TARGET, DATE_COLUMN]])
#
# File ~/.pyenv/versions/3.11.2/envs/lgbm-blog-2/lib/python3.11/site-packages/pandas/core/frame.py:5876, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5873     frame = self
#    5874 else:
#    5875     # GH 49473 Use "lazy copy" with Copy-on-Write
# -> 5876     frame = self.copy(deep=None)
#    5878 arrays: list[Index] = []
#    5879 names: list[Hashable] = []
#
# ...

# %% [markdown]
# ### Initialize models

# %%
direct_method = {
    lead: Model(model=LGBMRegressor(**params, verbose=-1), data=Data(data, leads=[lead], features=features))
    for lead in leads
}

single_model = Model(model=LGBMRegressor(**params, verbose=-1), data=MaskedData(data, leads=leads, features=features))

# %% [markdown]
# ### Run cross validation
# We forecast every day, but retrain only once every `retrain_frequency` days.

# %%
forecast_date = first_forecast_date

results = []

for i, forecast_date in enumerate(pd.date_range(first_forecast_date, periods=365, freq="D")):

    if not i % retrain_frequency:
        print(f"retraining model on {forecast_date}")

        # train separate models
        for lead, model in lead_models.items():
            X_train, y_train = model.data.get_train_data(forecast_date)
            model.model.fit(X_train, y_train)

        # train single model
        X_train, y_train = single_model.data.get_train_data(forecast_date)
        single_model.model.fit(X_train, y_train)

    # predict separate models
    for lead, model in lead_models.items():
        X_test, y_test = model.data.get_test_data(forecast_date)
        
        if X_test.empty:
            continue

        y_pred = model.model.predict(X_test)
        result = X_test.assign(y_pred=y_pred, y_test=y_test, forecast_date=forecast_date, model="lead")
        results.append(result)

    # predict single model
    X_test, y_test = single_model.data.get_test_data(forecast_date)
    
    if X_test.empty: 
        continue

    y_pred = single_model.model.predict(X_test)
    result = X_test.assign(y_pred=y_pred, y_test=y_test, forecast_date=forecast_date, model="single")
    results.append(result)

# %%
from datetime import datetime 
ts = datetime.now().strftime("%Y%m%d_%H_%M_%S")
file_name = f"{ts}_retrain_freq_{retrain_frequency}.parquet"
pd.concat(results).to_parquet(file_name)
print(f"Written results to {file_name}")
